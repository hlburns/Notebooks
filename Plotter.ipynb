# %%
import matplotlib.pyplot as plt

# %%
days=[3,10,30,100,300,1000]

# %%
NADW=[0.525,0.516, 0.387,0.465,1.116,0.584]
AABW=[0.271,0.264,0.404,0.267,0.376,0.222]
AAIW=[0.271,0.264,0.392,0.267,0.376,0.220]

# %%
#fig = figure()
A=plt.plot(days,NADW,'r',marker='+',)
B=plt.plot(days,AABW,'b',marker='+',)
C=plt.plot(days,AAIW,'k',marker='+',)
ax = plt.gca()
ax.set_xscale('log')
plt.title('Mean strength of overturning cells for each sponge restoring time')
plt.ylabel('Streamfuction (Sv)')
plt.xlabel('Sponge restoring timescale (days)')
#p = square(fc="r")
#legend([p], ["Red Rectangle"])
#plt.legend((A,B,C),('NADW Cell','AABW Cell','AAIW Cell'))
plt.savefig("/noc/users/hb1g13/Figures/Mobilis/Meanoverturn.jpg")
