# %%
from scipy.io import netcdf
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import sys
from scipy.interpolate import griddata
from pylab import *
from multiprocessing import Pool
from IPython.display import display, Math, Latex
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import rc
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
Comp="Mobilis"
OP="Ryan_myedits"
Years="0-10"
x="/noc/msm/scratch/students/hb1g13/"+Comp+"/"+OP+"/" 
os.chdir(x)

# %%
file3 = netcdf.NetCDFFile(Years+"rho.nc",'r')
rho=file3.variables['RHOAnoma']
Rho=rho[:,:,:,:]

# %%
x="/noc/msm/scratch/students/hb1g13/"+Comp+"/"+OP+"/glued_state_files" 
os.chdir(x)

# %%
file2= netcdf.NetCDFFile(Years+"all.nc",'r')
Temp=file2.variables['Temp']
Temp=Temp[:,:,:,:]
Yc=file2.variables['Y']
Y=Yc[:]
Z=file2.variables['Z']
Z=Z[:]

# %%
tref = np.genfromtxt('./Tref.file', delimiter = ',') 
tref=tref[:]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-57a04b94bda6> in <module>()
# ----> 1 tref = np.genfromtxt('./Tref.file', delimiter = ',')
#       2 tref=tref[:]
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skiprows, skip_header, skip_footer, converters, missing, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise)
#    1331     try:
#    1332         if isinstance(fname, basestring):
# -> 1333             fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1334             own_fhd = True
#    1335         else:
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/numpy/lib/_datasource.pyc in open(path, mode, destpath)
#     145
# ...

# %%
Tav=np.mean(Temp,axis=0)

# %%
x="/noc/msm/scratch/students/hb1g13/"+Comp+"/"+OP+"/grid/" 
os.chdir(x)

# %%
file2 = netcdf.NetCDFFile('grid.nc','r')
lm=file2.variables['HFacC']

# %%
Rhonil=999.8
tAlpha=2*10**-4
Tavlat=np.mean(Tav,axis=2)
Dens=np.zeros(shape(Tavlat))
Z=Z[:]
lm=lm[:]
lmc=np.array(lm)

# %%
lmc[lmc<1]=np.nan

# %%
for i in range(len(Z)):
          Dens[i,:]=Rhonil*(1-(tAlpha*(Tavlat[i,:]-tref[i])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-434d6d79ca99> in <module>()
#       1 for i in range(len(Z)):
# ----> 2           Dens[i,:]=Rhonil*(1-(tAlpha*(Tavlat[i,:]-tref[i])))
#
# NameError: name 'tref' is not defined

# %%
Dens=np.multiply(Dens,np.nanmean(lmc,axis=2))
#Densav=np.mean(Dens,axis=2)
#Densav[Densav==0]=np.nan
Dens[Dens==0]=np.nan
y=Y/1000

# %%
plt.clf()
D=np.linspace(np.nanmin(Dens), np.nanmax(Dens), num=9)
plt.contour(y,Z,Dens,30,cmap=cm.RdBu) #cmap options RdBu or RdYlBu or Spectral
cbar = plt.colorbar(ticks=D,format='%0.2f')
plt.title("Density Field")
plt.xlabel("Distance (km)")
plt.ylabel("Depth")
cbar.ax.set_ylabel(r"$Density \,\, kg/m^3$")
x="/noc/users/hb1g13/Figures/"+Comp+"/"+OP
os.chdir(x)
savefig("Density.png")
# Out:
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:220: RuntimeWarning: All-NaN axis encountered
#   warnings.warn("All-NaN axis encountered", RuntimeWarning)
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:319: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-eafac17120ee> in <module>()
#       1 plt.clf()
#       2 D=np.linspace(np.nanmin(Dens), np.nanmax(Dens), num=9)
# ----> 3 plt.contour(y,Z,Dens,30,cmap=cm.RdBu) #cmap options RdBu or RdYlBu or Spectral
#       4 cbar = plt.colorbar(ticks=D,format='%0.2f')
#       5 plt.title("Density Field")
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2630         ax.hold(hold)
# ...

# %%
rhotav=np.nanmean(Rho,axis=0)

# %%
rhotavzone=np.nanmean(rhotav,axis=2)+Rhonil

# %%
RHO=np.multiply(rhotavzone,np.nanmean(lmc,axis=2))

# %%
D=np.linspace(np.nanmin(RHO), np.nanmax(RHO), num=9)
plt.contour(y,Z,RHO,50,cmap=cm.RdBu)
#cbar = plt.colorbar()e
cbar = plt.colorbar(ticks=D,format='%0.2f')
plt.title(r'Density Field')
plt.xlabel('Distance (km)')
plt.ylabel('Depth')
cbar.ax.set_ylabel(r"$Density \,\, kg/m^3$")
x="/noc/users/hb1g13/Figures/"+Comp+"/"+OP
os.chdir(x)
savefig("Density.png")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-33-c9791c25fa09> in <module>()
#       8 cbar.ax.set_ylabel(r"$Density \,\, kg/m^3$")
#       9 x="/noc/users/hb1g13/Figures/"+Comp+"/"+OP
# ---> 10 os.chdir(x)
#      11 savefig("Density.png")
#
# OSError: [Errno 2] No such file or directory: '/noc/users/hb1g13/Figures/Mobilis/Ryan_myedits'
