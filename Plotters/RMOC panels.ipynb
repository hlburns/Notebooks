# %%
from scipy.io import netcdf
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import sys
import glob
import matplotlib.gridspec as gridspec

# %%
Year='280-300Psi.nc'

# %%
#tau=['3','10','30','100','300','1000','3000','10000','Closed']
#tau=['3','30','300','3000','10000','Closed']
tau=['3','300','3000','Closed']
x='/hpcdata/scratch/hb1g13/NchannelFlat'
#x='/noc/msm/scratch/students/hb1g13/Mobilis'

# %%
check=0
runs=[]
for i in range(len(tau)):
    flist=x+'/'+str(tau[i])+'daynokpp/'+Year
    if not os.path.exists(flist):
       print 'WARNING: '+flist+' does not exist! (skipping this ta\
u...)'
       check+=0
    else:
       check+=1
       runs.append(i)

# %%
Runs=np.array(runs)

# %%
fig=plt.figure(figsize=(20.0,20.0))
NADW=[]
AAIW=[]
SURF=[]
AABW=[]
for i in range(len(Runs)):
    fname=x+'/'+str(tau[Runs[i]])+'daynokpp/'+Year
    file2read = netcdf.NetCDFFile(fname,'r')
    lvrho=file2read.variables["LaVH1TH"]
    lvrho=lvrho[:]
    Y=file2read.variables['Yp1']
    Y=Y[:]
    time=file2read.variables['T']
    ti=time[:]
    dx=Y[1]-Y[0] # Find Resolution
    VT=np.sum(lvrho*dx,axis=3) #integrate Vdx along x
    VTfdz=np.cumsum(VT[:,::-1,:],axis=1) #sum up the water column
    psi=np.mean(VTfdz[:,::-1,:],axis=0)/10**6 #Time average and pu\
#t into Sv and put back in right order
    y=Y/1000
    z=np.array(range(1,60))
    Rho = np.genfromtxt(x+'/'+str(tau[Runs[i]])+'daynokpp/Temp', delimiter = ',')
    nolayers=len(psi[:,1])
    Rho=Rho[0:nolayers]#The layers package bins a layer so adjust \
    start=int(np.divide(ti[0],(86400*360)))#Find run start and sto\
    end=int(np.divide(ti[-1],(86400*360)))
    Q_levs = np.arange(-27.5,27.5,.75)
    Psi_levs = Q_levs / 10
    Q_ticks = np.arange(-27.5,27.5,5.)
    Psi_ticks = Q_ticks / 10
    #if np.max(abs(psi))>1:
    #   Psi_levs = (np.arange(-30,30)+0.5)/10
    ax = fig.add_subplot(2, 2, i+1)
    #CF=plt.subplot(3,2,i+1)
    surf=np.max(psi[22::,40:-40])
    psi[psi>2]=2 #Force scale
    p=ax.contourf(y,Rho,psi,Psi_levs,cmap=plt.cm.seismic) #Use b2r colourmap
    #clim(-1,1) # Put 0 to white
    #cbar=plt.colorbar(cf, ticks=Psi_ticks, shrink=0.8)
    ax.set_title(str(tau[Runs[i]])+'day',fontsize=40)
    #psineg = np.ma.masked_less(psi, 0)
    #psipos = np.ma.masked_greater(psi, 0)
    #nadw=np.sum(psipos[6:24,:])
    #aabw=np.sum(psineg[0:24,:])
    #aaiw=np.sum(psineg[24::,:])
    nadw=np.max(psi[6:22,40:-40])
    aabw=np.min(psi[0:24,50:-50])
    aaiw=np.min(psi[24::,40:-40])
    NADW.append(nadw)
    AABW.append(aabw)
    AAIW.append(aaiw)
    SURF.append(surf)
    if str(tau[Runs[i]])=='Closed':
        ax.set_title(str(tau[Runs[i]]),fontsize=40)
    ax.set_xlabel('Distance (km)',fontsize=40)
    ax.set_ylabel('Temperature $^o$C',fontsize=40)
    ax.tick_params(axis='both', which='major', labelsize=30)
    #cbar=plt.colorbar(p, ticks=Psi_ticks, shrink=0.8)
    #ax.set_clim(-1,1)
    #cbar.ax.set_ylabel('$\psi \,\, (sv)$')
plt.tight_layout()
cax = fig.add_axes([1, 0.1, 0.03, 0.8])
cbar=fig.colorbar(p, cax=cax,ticks=Psi_ticks)
cbar.ax.set_ylabel('$\psi \,\, (sv)$',fontsize=30)
cbar.ax.tick_params(labelsize=30)
q=( os.path.expanduser('~')+"/Figures/Mobilis")
if not os.path.exists(q):
       os.makedirs(q)
plt.savefig(q+"/Psirespanel"+str(start)+"-"+str(end)+".png")

# %%
tau[8]=100000
plt.plot(tau,abs(np.array(AABW)),label='AABW',marker='o')
plt.plot(tau,abs(np.array(NADW)),'r',label='NADW',marker='+')
plt.plot(tau,abs(np.array(AAIW)),label='AAIW',marker='^')
plt.xscale('log')
plt.xlabel(r'Relaxation timescale ($\tau$) in days')
plt.ylabel('ROC strength (Sv)')
plt.title('Max ROC for each cell')
lgd=plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
tau[8]='Closed'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-57956b75d5bc> in <module>()
#       1 tau[8]=100000
# ----> 2 plt.plot(tau,abs(np.array(AABW)),label='AABW',marker='o')
#       3 plt.plot(tau,abs(np.array(NADW)),'r',label='NADW',marker='+')
#       4 plt.plot(tau,abs(np.array(AAIW)),label='AAIW',marker='^')
#       5 plt.xscale('log')
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
# ...

# %%
tau[8]=100000
plt.plot(tau,abs(np.array(SURF)),'r',label='Surfacecell',marker='+')
plt.xscale('log')
plt.xlabel(r'Relaxation timescale ($\tau$) in days')
plt.ylabel('ROC strength (Sv)')
plt.title('Max strength of surface overturning cell')
lgd=plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
tau[8]='Closed'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-59b80bd854e1> in <module>()
#       1 tau[8]=100000
# ----> 2 plt.plot(tau,abs(np.array(SURF)),'r',label='Surfacecell',marker='+')
#       3 plt.xscale('log')
#       4 plt.xlabel(r'Relaxation timescale ($\tau$) in days')
#       5 plt.ylabel('ROC strength (Sv)')
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /noc/users/hb1g13/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
# ...

# %%
Zexp[20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6ed01f853765> in <module>()
# ----> 1 Zexp[20]
#
# NameError: name 'Zexp' is not defined
