# %%
from scipy.io import netcdf
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import sys
import glob
import matplotlib.gridspec as gridspec

# %%
Year='Tav.nc'

# %%
tau=['3','10','30','100','300','1000','3000','10000','Closed']
x='/noc/msm/scratch/students/hb1g13/Mobilis'

# %%
# Define a class that forces representation of float to look a certain way
# This remove trailing zero so '1.0' becomes '1'
class nf(float):
     def __repr__(self):
         str = '%.1f' % (self.__float__(),)
         if str[-1]=='0':
             return '%.0f' % self.__float__()
         else:
             return '%.1f' % self.__float__()

# %%
# Label levels with specially formatted floats
if plt.rcParams["text.usetex"]:
    fmt = r'%r %'
else:
    fmt = '%r '

# %%
check=0
runs=[]
for i in range(len(tau)):
    flist=x+'/'+str(tau[i])+'daynokpp/'+Year
    if not os.path.exists(flist):
       print 'WARNING: '+flist+' does not exist! (skipping this ta\
u...)'
       check+=0
    else:
       check+=1
       runs.append(i)

# %%
gridfilepath=x+'/'+str(tau[0])+'daynokpp/'
file2=netcdf.netcdf_file(gridfilepath+'grid.nc','r')
Zp1=file2.variables['Zp1']
Zp=Zp1[:]*1
Z=file2.variables['Z']
Z=Z[:]*1
Y=file2.variables['Y']
Y=Y[:]

# %%
Runs=np.array(runs)

# %%
fig=plt.figure(figsize=(12.5,12.5))
for i in range(len(Runs)):
    filename=x+'/'+str(tau[Runs[i]])+'daynokpp/'+Year
    file2read = netcdf.NetCDFFile(filename,'r')
    Temp=file2read.variables["THETA"]
    Temp=Temp[:]
    dx=Y[1]-Y[0] # Find Resolution
    Tzone=np.mean(np.squeeze(Temp*1),axis = 2)
    y =Y/1000
    Q_levs = (np.arange(0,8,0.5))
    Q_ticks = np.arange(0,8,1)
    ax = fig.add_subplot(3, 3, i+1)
    p=ax.contour(Y/1000,Z,Tzone,Q_levs,cmap=plt.cm.jet) #Use b2r colourmap
    #clim(-1,1) # Put 0 to white
    #cbar=plt.colorbar(cf, ticks=Psi_ticks, shrink=0.8)
    ax.set_title(str(tau[Runs[i]])+' day')
    if str(tau[Runs[i]])=='Closed':
        ax.set_title(str(tau[Runs[i]]))
    ax.set_xlabel('Distance (km)')
    ax.set_ylabel('Depth (m)')
    p.levels = [nf(val) for val in p.levels ]
    plt.clabel(p,p.levels[::2], inline=1,fmt=fmt, fontsize=10)#Label everyother contour 1sf
plt.tight_layout()
cax = fig.add_axes([1, 0.1, 0.03, 0.8])
cbar=fig.colorbar(p, cax=cax,ticks=Q_ticks)
cbar.ax.set_ylabel('$Temp \,\, ^oC$')
q=( os.path.expanduser('~')+"/Figures/Mobilis")
if not os.path.exists(q):
       os.makedirs(q)
plt.savefig(q+"/Temppanel.pdf",bbox_extra_artists=(cbar))
